# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:13, 2.30MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]
print(type(int_words))
print(len(int_to_vocab))
# Out:
# <class 'list'>
# 63641

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
import math as mth
import random

def get_probability(param_t,freq_w):
    return 1.0 - mth.sqrt(param_t/freq_w)

t = 5 # threshold parameter

# evaluate frequency table of each word
import collections as coll
counter = coll.Counter(int_words)
p_drop = {}

for val in counter.keys():
    #print(val,counter[val])
    discard_prob = get_probability(t,counter[val]) 
    p_drop[val] = discard_prob

#print(p_drop)
train_words = [word for word in int_words if p_drop[word] < random.random()]
#print(train_words)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    #print("start: ",start)
    stop = idx + R
    #print("stop: ",stop)
    #print("words in range: ",words[start:stop+1])
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    #print("left: ",words[start:idx], "word: ",words[idx]," right: ", words[idx+1:stop+1])
    #print("target_words: ",target_words)
    return list(target_words)    

window_size = 7
idx = 4
print ("target: ",get_target(train_words, idx, window_size))
# Out:
# target:  [6753, 741, 45613, 371, 566, 5240, 61882, 54013]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

example_words = train_words[0:50]
print("example words: ",example_words)

example_batch_size = 5
example_window_size = 7
example_batches = get_batches(example_words, example_batch_size, example_window_size)

for x,y in example_batches:
    print(" ")
    print("x: ",x)
    print("y: ",y)
# Out:
# example words:  [5240, 741, 61882, 371, 7102, 45613, 6753, 566, 54013, 8134, 7102, 2312, 1821, 2515, 15169, 3058, 14749, 57039, 16470, 30697, 56907, 3817, 26267, 2536, 242, 5241, 6474, 551, 44074, 56030, 40641, 259, 14859, 817, 1290, 5232, 17208, 14022, 30744, 59079, 10, 13026, 1, 15497, 258, 14516, 2655, 30098, 2916, 18845]
#
# x:  [5240, 741, 741, 741, 741, 61882, 61882, 61882, 61882, 371, 371, 371, 371, 7102]
# y:  [741, 5240, 61882, 371, 7102, 5240, 371, 741, 7102, 5240, 61882, 741, 7102, 371]
#
# x:  [45613, 45613, 45613, 45613, 6753, 6753, 566, 566, 566, 566, 54013, 54013, 54013, 54013, 8134, 8134, 8134, 8134]
# y:  [6753, 54013, 566, 8134, 45613, 566, 6753, 54013, 45613, 8134, 6753, 45613, 566, 8134, 6753, 54013, 45613, 566]
#
# x:  [7102, 7102, 7102, 7102, 2312, 2312, 2312, 2312, 1821, 1821, 2515, 2515, 2515, 2515, 15169, 15169, 15169, 15169]
# y:  [2312, 15169, 2515, 1821, 15169, 2515, 1821, 7102, 2312, 2515, 2312, 15169, 1821, 7102, 2312, 2515, 1821, 7102]
#
# x:  [3058, 3058, 14749, 14749, 57039, 57039, 57039, 57039, 16470, 16470, 16470, 16470, 30697]
# y:  [14749, 57039, 3058, 57039, 30697, 3058, 14749, 16470, 30697, 3058, 14749, 57039, 16470]
#
# x:  [56907, 56907, 3817, 3817, 3817, 3817, 26267, 26267, 26267, 26267, 2536, 2536, 2536, 2536, 242, 242]
# y:  [3817, 26267, 2536, 242, 56907, 26267, 2536, 3817, 242, 56907, 3817, 242, 56907, 26267, 2536, 26267]
#
# x:  [5241, 6474, 6474, 6474, 6474, 551, 551, 551, 551, 44074, 44074, 44074, 56030, 56030, 56030, 56030]
# y:  [6474, 5241, 44074, 56030, 551, 5241, 6474, 44074, 56030, 6474, 56030, 551, 5241, 6474, 44074, 551]
#
# x:  [40641, 40641, 40641, 40641, 259, 259, 259, 14859, 14859, 14859, 14859, 817, 817, 817, 817, 1290, 1290]
# y:  [14859, 817, 1290, 259, 40641, 14859, 817, 40641, 1290, 259, 817, 14859, 40641, 1290, 259, 817, 14859]
#
# x:  [5232, 17208, 17208, 17208, 17208, 14022, 14022, 14022, 14022, 30744, 30744, 30744, 30744, 59079, 59079, 59079, 59079]
# y:  [17208, 5232, 30744, 14022, 59079, 5232, 30744, 17208, 59079, 5232, 17208, 14022, 59079, 5232, 30744, 17208, 14022]
#
# x:  [10, 10, 13026, 13026, 13026, 13026, 1, 1, 1, 1, 15497, 15497, 15497, 15497, 258, 258]
# y:  [1, 13026, 258, 1, 10, 15497, 15497, 10, 258, 13026, 1, 10, 258, 13026, 1, 15497]
#
# x:  [14516, 14516, 14516, 14516, 2655, 2655, 2655, 2655, 30098, 30098, 2916, 2916, 2916, 2916, 18845]
# y:  [30098, 2916, 18845, 2655, 2916, 30098, 14516, 18845, 2916, 2655, 30098, 14516, 18845, 2655, 2916]

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,[None],name="inputs")
    labels = tf.placeholder(tf.int32,[None,None],name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1.0, 1.0))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding),stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b,
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):

        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 4.9846 0.1138 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.0384 0.1125 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.0379 0.1137 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 4.9601 0.1148 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 4.9967 0.1139 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 4.9474 0.1142 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 4.9610 0.1135 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.0038 0.1134 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.9944 0.1171 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.9442 0.1158 sec/batch
# Nearest to than: heritages, marva, ulfilas, begum, canoeing, celera, murat, watergate,
# Nearest to be: pomeranian, fermented, apollon, windsor, pulau, jumpers, rapp, valhalla,
# Nearest to world: lectionis, pinckney, kingston, politician, millennial, boson, soldiers, boarder,
# Nearest to one: scratches, animist, bowell, deny, motto, circe, democratic, penicillin,
# Nearest to used: dianetic, interconnected, benzyl, decides, fuca, pivot, jumpers, ordinals,
# Nearest to or: witchcraft, keystroke, sixth, syllabics, imbued, molecular, govern, pinafore,
# Nearest to american: sync, arminians, civilizing, horkheimer, buffalo, bourgeois, nutt, ended,
# Nearest to when: kamchatsky, malnutrition, colic, villi, coucy, arabic, diploid, race,
# Nearest to woman: werewolves, philistia, symbolically, algorithms, wrestle, airlifter, reloading, danorum,
# Nearest to applied: anchors, maribor, spilled, stamps, dynasty, scrap, philly, bladder,
# Nearest to recorded: ants, nauk, presbyterianism, musa, howling, chickie, glasnost, aggravating,
# Nearest to defense: much, maseru, renovated, keywork, herring, grouse, performa, lawless,
# Nearest to pre: corn, subtitles, natures, assemblies, partition, ultrasonography, wg, mccartney,
# Nearest to http: lowers, helpdesk, sadozai, corning, collectivit, washes, altruistic, stormy,
# Nearest to test: fulfilment, conserving, gabler, thrived, robby, propanone, succesor, hive,
# Nearest to applications: kazimierz, curt, meatball, teleport, stipulation, proficient, rojas, absorbing,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.9460 0.1201 sec/batch
# Epoch 2/10 Iteration: 1200 Avg. Training loss: 4.8445 0.0990 sec/batch
# Epoch 2/10 Iteration: 1300 Avg. Training loss: 4.8187 0.1170 sec/batch
# Epoch 2/10 Iteration: 1400 Avg. Training loss: 4.7950 0.1172 sec/batch
# Epoch 2/10 Iteration: 1500 Avg. Training loss: 4.7397 0.1185 sec/batch
# Epoch 2/10 Iteration: 1600 Avg. Training loss: 4.7301 0.1170 sec/batch
# Epoch 2/10 Iteration: 1700 Avg. Training loss: 4.7504 0.1194 sec/batch
# Epoch 2/10 Iteration: 1800 Avg. Training loss: 4.6906 0.1156 sec/batch
# Epoch 2/10 Iteration: 1900 Avg. Training loss: 4.7290 0.1176 sec/batch
# Epoch 2/10 Iteration: 2000 Avg. Training loss: 4.6913 0.1185 sec/batch
# Nearest to than: heritages, marva, ulfilas, watergate, begum, canoeing, murat, quelling,
# Nearest to be: pomeranian, fermented, jumpers, windsor, inteligencia, coolers, rapp, apollon,
# Nearest to world: soldiers, politician, recites, kingston, signing, millennial, boarder, pinckney,
# Nearest to one: scratches, deny, democratic, animist, bowell, motto, that, circe,
# Nearest to used: dianetic, interconnected, jumpers, benzyl, decides, fuca, pivot, teamwork,
# Nearest to or: molecular, syllabics, sixth, witchcraft, keystroke, gear, powerpc, imbued,
# Nearest to american: sync, civilizing, arminians, ended, horkheimer, buffalo, bourgeois, panama,
# Nearest to when: kamchatsky, colic, malnutrition, villi, coucy, race, arabic, csu,
# Nearest to woman: philistia, werewolves, michelob, symbolically, reloading, recreates, algorithms, wrestle,
# Nearest to applied: anchors, scrap, stamps, philly, legalized, swedish, dynasty, maribor,
# Nearest to recorded: nauk, ants, glasnost, presbyterianism, chickie, howling, causing, musa,
# Nearest to defense: keywork, much, maseru, renovated, herring, performa, lawless, abbadie,
# Nearest to pre: natures, subtitles, corn, assemblies, partition, du, purses, ultrasonography,
# Nearest to http: lowers, sadozai, helpdesk, collectivit, gast, altruistic, corning, goebel,
# Nearest to test: fulfilment, conserving, succesor, gabler, robby, thrived, propanone, cosine,
# Nearest to applications: kazimierz, curt, teleport, meatball, absorbing, deductive, rojas, teutoburg,
# Epoch 2/10 Iteration: 2100 Avg. Training loss: 4.6488 0.1176 sec/batch
# Epoch 2/10 Iteration: 2200 Avg. Training loss: 4.6587 0.1189 sec/batch
# Epoch 3/10 Iteration: 2300 Avg. Training loss: 4.5693 0.0804 sec/batch
# Epoch 3/10 Iteration: 2400 Avg. Training loss: 4.5048 0.1174 sec/batch
# Epoch 3/10 Iteration: 2500 Avg. Training loss: 4.5278 0.1164 sec/batch
# Epoch 3/10 Iteration: 2600 Avg. Training loss: 4.4893 0.1172 sec/batch
# Epoch 3/10 Iteration: 2700 Avg. Training loss: 4.4299 0.1164 sec/batch
# Epoch 3/10 Iteration: 2800 Avg. Training loss: 4.4609 0.1161 sec/batch
# Epoch 3/10 Iteration: 2900 Avg. Training loss: 4.4233 0.1160 sec/batch
# Epoch 3/10 Iteration: 3000 Avg. Training loss: 4.4533 0.1164 sec/batch
# Nearest to than: marva, canoeing, watergate, heritages, presiding, begum, quelling, ulfilas,
# Nearest to be: pomeranian, fermented, jumpers, windsor, inteligencia, seville, valhalla, coolers,
# Nearest to world: soldiers, politician, signing, recites, kingston, boarder, empirical, millennial,
# Nearest to one: scratches, motto, bowell, animist, deny, democratic, usa, penicillin,
# Nearest to used: interconnected, dianetic, solar, decides, jumpers, fuca, pivot, ordinals,
# Nearest to or: molecular, sixth, gear, keystroke, syllabics, powerpc, witchcraft, vocalist,
# Nearest to american: sync, arminians, buffalo, mover, civilizing, bourgeois, clowns, ended,
# Nearest to when: kamchatsky, malnutrition, colic, arabic, race, warrants, instances, villi,
# Nearest to woman: philistia, algorithms, oppress, michelob, scarlet, recreates, stake, bot,
# Nearest to applied: anchors, scrap, dynasty, swedish, changes, primal, dub, stamps,
# Nearest to recorded: nauk, ants, causing, glasnost, chickie, politician, presbyterianism, canned,
# Nearest to defense: much, keywork, renovated, maseru, herring, performa, grouse, adapted,
# Nearest to pre: natures, subtitles, design, assemblies, du, corn, partition, mccartney,
# Nearest to http: lowers, sadozai, parliamentarians, gast, altruistic, helpdesk, goebel, collectivit,
# Nearest to test: fulfilment, conserving, succesor, gabler, thrived, slave, suisse, cosine,
# Nearest to applications: kazimierz, curt, teleport, deductive, controlled, absorbing, around, meatball,
# Epoch 3/10 Iteration: 3100 Avg. Training loss: 4.4595 0.1209 sec/batch
# Epoch 3/10 Iteration: 3200 Avg. Training loss: 4.4452 0.1191 sec/batch
# Epoch 3/10 Iteration: 3300 Avg. Training loss: 4.3888 0.1177 sec/batch
# Epoch 4/10 Iteration: 3400 Avg. Training loss: 4.3739 0.0608 sec/batch
# Epoch 4/10 Iteration: 3500 Avg. Training loss: 4.2751 0.1188 sec/batch
# Epoch 4/10 Iteration: 3600 Avg. Training loss: 4.3100 0.1174 sec/batch
# Epoch 4/10 Iteration: 3700 Avg. Training loss: 4.3176 0.1183 sec/batch
# Epoch 4/10 Iteration: 3800 Avg. Training loss: 4.2800 0.1175 sec/batch
# Epoch 4/10 Iteration: 3900 Avg. Training loss: 4.2803 0.1181 sec/batch
# Epoch 4/10 Iteration: 4000 Avg. Training loss: 4.2494 0.1168 sec/batch
# Nearest to than: marva, canoeing, heritages, presiding, begum, eponymous, watergate, lyric,
# Nearest to be: fermented, pomeranian, jumpers, rapp, coolers, valhalla, windsor, seville,
# Nearest to world: soldiers, kingston, boarder, recites, signing, millennial, politician, pinckney,
# Nearest to one: bowell, scratches, animist, motto, amidst, hide, usa, wrangel,
# Nearest to used: interconnected, dianetic, jumpers, pivot, solar, charset, fuca, decides,
# Nearest to or: sixth, keystroke, gear, witchcraft, molecular, syllabics, powerpc, vocalist,
# Nearest to american: sync, mover, arminians, buffalo, bourgeois, clowns, civilizing, decrypted,
# Nearest to when: malnutrition, kamchatsky, colic, arabic, instances, race, oil, warrants,
# Nearest to woman: philistia, algorithms, michelob, recreates, scarlet, oppress, hentai, bot,
# Nearest to applied: dynasty, anchors, scrap, stamps, changes, conformity, primal, media,
# Nearest to recorded: ants, nauk, canned, chickie, causing, glossaries, ichkeria, glasnost,
# Nearest to defense: much, keywork, renovated, maseru, adapted, herring, performa, bowell,
# Nearest to pre: natures, subtitles, du, design, corn, partition, assemblies, mccartney,
# Nearest to http: lowers, sadozai, parliamentarians, helpdesk, goebel, altruistic, scalability, collectivit,
# Nearest to test: fulfilment, succesor, conserving, cosine, thrived, slave, gabler, suisse,
# Nearest to applications: kazimierz, curt, controlled, teleport, erosion, deductive, absorbing, around,
# Epoch 4/10 Iteration: 4100 Avg. Training loss: 4.2772 0.1188 sec/batch
# Epoch 4/10 Iteration: 4200 Avg. Training loss: 4.2838 0.1159 sec/batch
# Epoch 4/10 Iteration: 4300 Avg. Training loss: 4.3049 0.1176 sec/batch
# Epoch 4/10 Iteration: 4400 Avg. Training loss: 4.2489 0.1172 sec/batch
# Epoch 5/10 Iteration: 4500 Avg. Training loss: 4.2506 0.0440 sec/batch
# Epoch 5/10 Iteration: 4600 Avg. Training loss: 4.1580 0.1178 sec/batch
# Epoch 5/10 Iteration: 4700 Avg. Training loss: 4.1862 0.1179 sec/batch
# Epoch 5/10 Iteration: 4800 Avg. Training loss: 4.1776 0.1165 sec/batch
# Epoch 5/10 Iteration: 4900 Avg. Training loss: 4.1588 0.1176 sec/batch
# Epoch 5/10 Iteration: 5000 Avg. Training loss: 4.2073 0.1171 sec/batch
# Nearest to than: marva, heritages, eponymous, presiding, canoeing, bracelets, recalcitrant, lyric,
# Nearest to be: fermented, pomeranian, jumpers, coolers, rapp, valhalla, seville, stored,
# Nearest to world: kingston, soldiers, refueling, boarder, signing, recites, millennial, lectionis,
# Nearest to one: bowell, amidst, animist, scratches, motto, singer, wrangel, hide,
# Nearest to used: interconnected, dianetic, charset, solar, ordinals, pivot, jumpers, calibrated,
# Nearest to or: molecular, keystroke, cells, gear, sixth, solid, witchcraft, entertains,
# Nearest to american: mover, arminians, buffalo, bourgeois, sync, decrypted, matthew, clowns,
# Nearest to when: malnutrition, kamchatsky, colic, arabic, dramatised, brightest, instances, oil,
# Nearest to woman: hentai, philistia, danorum, michelob, symbolically, bot, scarlet, algorithms,
# Nearest to applied: dynasty, conformity, anchors, changes, dub, scrap, philly, media,
# Nearest to recorded: canned, ants, nauk, chickie, glossaries, ichkeria, causing, presbyterianism,
# Nearest to defense: keywork, much, renovated, maseru, adapted, performa, lawless, herring,
# Nearest to pre: natures, subtitles, du, design, partition, corn, mccartney, assemblies,
# Nearest to http: lowers, sadozai, helpdesk, goebel, parliamentarians, collectivit, salvific, scalability,
# Nearest to test: fulfilment, succesor, conserving, cosine, gabler, robby, slave, thrived,
# Nearest to applications: controlled, kazimierz, erosion, teleport, sapho, curt, deductive, meatball,
# Epoch 5/10 Iteration: 5100 Avg. Training loss: 4.1832 0.1200 sec/batch
# Epoch 5/10 Iteration: 5200 Avg. Training loss: 4.1636 0.1175 sec/batch
# Epoch 5/10 Iteration: 5300 Avg. Training loss: 4.1861 0.1178 sec/batch
# Epoch 5/10 Iteration: 5400 Avg. Training loss: 4.1567 0.1178 sec/batch
# Epoch 5/10 Iteration: 5500 Avg. Training loss: 4.1767 0.1175 sec/batch
# Epoch 6/10 Iteration: 5600 Avg. Training loss: 4.1592 0.0232 sec/batch
# Epoch 6/10 Iteration: 5700 Avg. Training loss: 4.0767 0.1180 sec/batch
# Epoch 6/10 Iteration: 5800 Avg. Training loss: 4.0752 0.1180 sec/batch
# Epoch 6/10 Iteration: 5900 Avg. Training loss: 4.0958 0.1159 sec/batch
# Epoch 6/10 Iteration: 6000 Avg. Training loss: 4.0735 0.1166 sec/batch
# Nearest to than: marva, heritages, bracelets, canoeing, eponymous, recalcitrant, presiding, almanack,
# Nearest to be: fermented, jumpers, pomeranian, coolers, rapp, seville, stored, appear,
# Nearest to world: kingston, soldiers, boarder, lectionis, refueling, recites, signing, favourably,
# Nearest to one: bowell, amidst, animist, scratches, singer, motto, sackville, wrangel,
# Nearest to used: interconnected, charset, dianetic, solar, ordinals, pivot, jumpers, pairs,
# Nearest to or: molecular, gear, keystroke, entertains, cells, solid, ingested, emit,
# Nearest to american: mover, arminians, comedian, buffalo, bourgeois, matthew, arendt, decrypted,
# Nearest to when: malnutrition, kamchatsky, colic, dramatised, lettre, unpaired, outburst, brightest,
# Nearest to woman: hentai, danorum, philistia, airlifter, werewolves, scarlet, symbolically, girt,
# Nearest to applied: anchors, conformity, philly, changes, dynasty, dub, ci, scrap,
# Nearest to recorded: canned, ants, nauk, chickie, ichkeria, halabja, glossaries, howling,
# Nearest to defense: keywork, renovated, maseru, much, adapted, lawless, bowell, performa,
# Nearest to pre: subtitles, natures, du, design, partition, ultrasonography, rearguard, purses,
# Nearest to http: lowers, helpdesk, sadozai, collectivit, goebel, salvific, parliamentarians, ills,
# Nearest to test: fulfilment, succesor, cosine, conserving, gabler, slave, exporting, robby,
# Nearest to applications: controlled, sapho, deductive, absorbing, teleport, kazimierz, meatball, erosion,
# Epoch 6/10 Iteration: 6100 Avg. Training loss: 4.0577 0.1169 sec/batch
# Epoch 6/10 Iteration: 6200 Avg. Training loss: 4.0673 0.1186 sec/batch
# Epoch 6/10 Iteration: 6300 Avg. Training loss: 4.0647 0.1179 sec/batch
# Epoch 6/10 Iteration: 6400 Avg. Training loss: 4.0619 0.1178 sec/batch
# Epoch 6/10 Iteration: 6500 Avg. Training loss: 4.0686 0.1186 sec/batch
# Epoch 6/10 Iteration: 6600 Avg. Training loss: 4.0549 0.1158 sec/batch
# Epoch 7/10 Iteration: 6700 Avg. Training loss: 4.0595 0.0047 sec/batch
# Epoch 7/10 Iteration: 6800 Avg. Training loss: 3.9925 0.1182 sec/batch
# Epoch 7/10 Iteration: 6900 Avg. Training loss: 4.0062 0.1154 sec/batch
# Epoch 7/10 Iteration: 7000 Avg. Training loss: 4.0045 0.1178 sec/batch
# Nearest to than: marva, bracelets, heritages, maule, eponymous, anglia, canoeing, recalcitrant,
# Nearest to be: fermented, jumpers, pomeranian, coolers, appear, rapp, seville, spectroscopy,
# Nearest to world: kingston, boarder, refueling, lectionis, recites, soldiers, signing, pinckney,
# Nearest to one: bowell, animist, amidst, singer, sackville, finch, scratches, wrangel,
# Nearest to used: interconnected, charset, solar, ordinals, dianetic, pairs, bootlegged, content,
# Nearest to or: molecular, cells, gear, keystroke, entertains, syllabics, ditto, emit,
# Nearest to american: comedian, arminians, mover, buffalo, arendt, todd, actress, matthew,
# Nearest to when: malnutrition, kamchatsky, colic, dramatised, outburst, prefetch, hyperlinked, unpaired,
# Nearest to woman: hentai, danorum, werewolves, airlifter, scarlet, girt, beatrice, symbolically,
# Nearest to applied: conformity, anchors, electromagnetism, scrap, ci, changes, dynasty, transmissible,
# Nearest to recorded: ants, canned, ichkeria, nauk, glossaries, chickie, presbyterianism, moralistic,
# Nearest to defense: keywork, adapted, renovated, maseru, much, lawless, bowell, fijian,
# Nearest to pre: natures, subtitles, du, design, ultrasonography, sponsorships, assemblies, rye,
# Nearest to http: helpdesk, lowers, sadozai, kovi, salvific, collectivit, goebel, parliamentarians,
# Nearest to test: succesor, fulfilment, cosine, conserving, slave, gabler, robby, exporting,
# Nearest to applications: sapho, controlled, absorbing, teleport, deductive, erosion, meatball, proficient,
# Epoch 7/10 Iteration: 7100 Avg. Training loss: 3.9726 0.1177 sec/batch
# Epoch 7/10 Iteration: 7200 Avg. Training loss: 3.9704 0.1169 sec/batch
# Epoch 7/10 Iteration: 7300 Avg. Training loss: 3.9787 0.1171 sec/batch
# Epoch 7/10 Iteration: 7400 Avg. Training loss: 3.9955 0.1162 sec/batch
# Epoch 7/10 Iteration: 7500 Avg. Training loss: 4.0027 0.1173 sec/batch
# Epoch 7/10 Iteration: 7600 Avg. Training loss: 3.9902 0.1160 sec/batch
# Epoch 7/10 Iteration: 7700 Avg. Training loss: 3.9566 0.1166 sec/batch
# Epoch 7/10 Iteration: 7800 Avg. Training loss: 3.9746 0.1164 sec/batch
# Epoch 8/10 Iteration: 7900 Avg. Training loss: 3.9292 0.1031 sec/batch
# Epoch 8/10 Iteration: 8000 Avg. Training loss: 3.8898 0.1153 sec/batch
# Nearest to than: marva, bracelets, heritages, maule, benelli, eponymous, almanack, anglia,
# Nearest to be: fermented, coolers, jumpers, pomeranian, rapp, appear, spectroscopy, seville,
# Nearest to world: boarder, kingston, recites, refueling, lectionis, soldiers, hilo, loti,
# Nearest to one: bowell, sackville, singer, animist, amidst, finch, politican, wrangel,
# Nearest to used: charset, interconnected, solar, ordinals, pairs, bootlegged, content, dianetic,
# Nearest to or: molecular, ditto, emit, cells, entertains, witchcraft, gear, keystroke,
# Nearest to american: comedian, actress, todd, arminians, mover, arendt, choreographer, brian,
# Nearest to when: malnutrition, kamchatsky, dramatised, colic, ancients, outburst, unpaired, prefetch,
# Nearest to woman: hentai, danorum, werewolves, zimri, scarlet, beatrice, airlifter, girt,
# Nearest to applied: conformity, anchors, electromagnetism, ci, transmissible, philly, marsupialia, changes,
# Nearest to recorded: canned, ants, glossaries, ichkeria, nauk, dixit, chickie, collaboration,
# Nearest to defense: keywork, adapted, lawless, much, maseru, fijian, renovated, scherzo,
# Nearest to pre: natures, du, subtitles, design, rye, fiesole, ultrasonography, sponsorships,
# Nearest to http: helpdesk, sadozai, kovi, lowers, bain, verizon, smtp, salvific,
# Nearest to test: succesor, fulfilment, cosine, conserving, slave, suisse, gabler, robby,
# Nearest to applications: sapho, absorbing, controlled, teleport, deductive, meatball, proficient, erosion,
# Epoch 8/10 Iteration: 8100 Avg. Training loss: 3.8763 0.1178 sec/batch
# Epoch 8/10 Iteration: 8200 Avg. Training loss: 3.8958 0.1156 sec/batch
# Epoch 8/10 Iteration: 8300 Avg. Training loss: 3.9048 0.1157 sec/batch
# Epoch 8/10 Iteration: 8400 Avg. Training loss: 3.8501 0.1166 sec/batch
# Epoch 8/10 Iteration: 8500 Avg. Training loss: 3.8660 0.1146 sec/batch
# Epoch 8/10 Iteration: 8600 Avg. Training loss: 3.9165 0.1159 sec/batch
# Epoch 8/10 Iteration: 8700 Avg. Training loss: 3.9100 0.1174 sec/batch
# Epoch 8/10 Iteration: 8800 Avg. Training loss: 3.8620 0.1150 sec/batch
# Epoch 8/10 Iteration: 8900 Avg. Training loss: 3.8612 0.1157 sec/batch
# Epoch 9/10 Iteration: 9000 Avg. Training loss: 3.8304 0.0837 sec/batch
# Nearest to than: marva, bracelets, heritages, eponymous, benelli, relays, almanack, maule,
# Nearest to be: fermented, coolers, jumpers, appear, spectroscopy, pomeranian, rapp, seville,
# Nearest to world: boarder, recites, kingston, refueling, loti, pinckney, opted, hilo,
# Nearest to one: bowell, sackville, amidst, singer, finch, animist, politican, wrangel,
# Nearest to used: charset, interconnected, solar, pairs, ordinals, content, bootlegged, benzyl,
# Nearest to or: emit, keystroke, ditto, mari, paracelsus, witchcraft, gear, cells,
# Nearest to american: comedian, actress, todd, arendt, arminians, mover, stauffenberg, brian,
# Nearest to when: malnutrition, kamchatsky, dramatised, colic, ancients, outburst, unpaired, prefetch,
# Nearest to woman: hentai, danorum, zimri, beatrice, scarlet, god, airlifter, werewolves,
# Nearest to applied: conformity, electromagnetism, anchors, marsupialia, ci, transmissible, changes, scrap,
# Nearest to recorded: canned, ants, glossaries, ichkeria, nauk, collaboration, moralistic, carcinogen,
# Nearest to defense: keywork, fijian, adapted, lawless, maseru, locating, much, performa,
# Nearest to pre: du, natures, subtitles, design, rye, fiesole, rearguard, buckwheat,
# Nearest to http: helpdesk, kovi, verizon, sadozai, bain, smtp, lowers, collectivit,
# Nearest to test: succesor, fulfilment, cosine, mwi, slave, conserving, suisse, exporting,
# Nearest to applications: absorbing, sapho, controlled, teleport, deductive, proficient, meatball, controllers,
# Epoch 9/10 Iteration: 9100 Avg. Training loss: 3.7781 0.1169 sec/batch
# Epoch 9/10 Iteration: 9200 Avg. Training loss: 3.8235 0.1178 sec/batch
# Epoch 9/10 Iteration: 9300 Avg. Training loss: 3.7736 0.1147 sec/batch
# Epoch 9/10 Iteration: 9400 Avg. Training loss: 3.7608 0.1160 sec/batch
# Epoch 9/10 Iteration: 9500 Avg. Training loss: 3.7973 0.1147 sec/batch
# Epoch 9/10 Iteration: 9600 Avg. Training loss: 3.7644 0.1190 sec/batch
# Epoch 9/10 Iteration: 9700 Avg. Training loss: 3.8031 0.1162 sec/batch
# Epoch 9/10 Iteration: 9800 Avg. Training loss: 3.8122 0.1184 sec/batch
# Epoch 9/10 Iteration: 9900 Avg. Training loss: 3.7791 0.1158 sec/batch
# Epoch 9/10 Iteration: 10000 Avg. Training loss: 3.7496 0.1164 sec/batch
# Nearest to than: marva, heritages, bracelets, eponymous, benelli, maule, anglia, respectfully,
# Nearest to be: fermented, spectroscopy, appear, jumpers, coolers, rapp, seville, pomeranian,
# Nearest to world: boarder, pinckney, refueling, recites, opted, kingston, loti, advertisers,
# Nearest to one: bowell, sackville, amidst, finch, singer, five, wrangel, b,
# Nearest to used: charset, solar, ordinals, pairs, interconnected, content, benzyl, bootlegged,
# Nearest to or: emit, ditto, keystroke, mari, tsk, caco, cells, samarium,
# Nearest to american: comedian, actress, mover, arendt, todd, choreographer, stauffenberg, arminians,
# Nearest to when: malnutrition, dramatised, kamchatsky, colic, ancients, merged, outburst, unpaired,
# Nearest to woman: hentai, danorum, zimri, scarlet, beatrice, airlifter, girt, werewolves,
# Nearest to applied: conformity, marsupialia, dissertation, electromagnetism, philly, roam, ci, petrarch,
# Nearest to recorded: canned, glossaries, ants, ichkeria, playing, collaboration, carcinogen, nauk,
# Nearest to defense: keywork, fijian, adapted, lawless, islami, nazis, amnesty, scherzo,
# Nearest to pre: natures, du, subtitles, design, rye, fiesole, dwellings, sponsorships,
# Nearest to http: helpdesk, kovi, verizon, smtp, bain, sadozai, ills, lowers,
# Nearest to test: succesor, fulfilment, cosine, mwi, conserving, chao, exporting, slave,
# Nearest to applications: absorbing, sapho, teleport, controlled, deductive, proficient, controllers, meatball,
# Epoch 10/10 Iteration: 10100 Avg. Training loss: 3.7666 0.0658 sec/batch
# Epoch 10/10 Iteration: 10200 Avg. Training loss: 3.7129 0.1167 sec/batch
# Epoch 10/10 Iteration: 10300 Avg. Training loss: 3.7112 0.1154 sec/batch
# Epoch 10/10 Iteration: 10400 Avg. Training loss: 3.6690 0.1173 sec/batch
# Epoch 10/10 Iteration: 10500 Avg. Training loss: 3.6964 0.1154 sec/batch
# Epoch 10/10 Iteration: 10600 Avg. Training loss: 3.7326 0.1157 sec/batch
# Epoch 10/10 Iteration: 10700 Avg. Training loss: 3.7318 0.1166 sec/batch
# Epoch 10/10 Iteration: 10800 Avg. Training loss: 3.7219 0.1168 sec/batch
# Epoch 10/10 Iteration: 10900 Avg. Training loss: 3.6974 0.1158 sec/batch
# Epoch 10/10 Iteration: 11000 Avg. Training loss: 3.7307 0.1168 sec/batch
# Nearest to than: marva, heritages, bracelets, eponymous, benelli, maule, respectfully, anglia,
# Nearest to be: fermented, rapp, appear, spectroscopy, jumpers, coolers, seville, egoists,
# Nearest to world: boarder, refueling, opted, recites, advertisers, outlays, errands, tenacity,
# Nearest to one: bowell, sackville, amidst, finch, five, singer, wrangel, zaghawa,
# Nearest to used: solar, charset, ordinals, interconnected, pairs, content, benzyl, simulant,
# Nearest to or: mari, tsk, ditto, caco, keystroke, sixth, emit, melodically,
# Nearest to american: actress, mover, comedian, todd, stauffenberg, arendt, backstreet, demme,
# Nearest to when: malnutrition, dramatised, ancients, kamchatsky, colic, outburst, merged, unpaired,
# Nearest to woman: hentai, danorum, zimri, scarlet, unencumbered, god, airlifter, revealing,
# Nearest to applied: conformity, marsupialia, dissertation, roam, electromagnetism, philly, petrarch, airbags,
# Nearest to recorded: canned, playing, collaboration, ichkeria, ants, glossaries, carcinogen, band,
# Nearest to defense: fijian, keywork, nazis, amnesty, lawless, islami, adapted, excommunications,
# Nearest to pre: du, natures, subtitles, design, rye, buckwheat, sponsorships, dwellings,
# Nearest to http: kovi, helpdesk, verizon, smtp, goebel, sadozai, bain, salvific,
# Nearest to test: succesor, fulfilment, mwi, robby, cosine, exporting, slave, chao,
# Nearest to applications: absorbing, sapho, controlled, teleport, deductive, proficient, controllers, manipulating,
# Epoch 10/10 Iteration: 11100 Avg. Training loss: 3.6910 0.1171 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
